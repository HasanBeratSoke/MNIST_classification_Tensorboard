# %%
from PIL import ImageTk, Image, ImageDraw, ImageGrab
import PIL
from tkinter import *
import tkinter as tk
import cv2 as cv

# %%
width = 150  # canvas width
height = 150 # canvas height
center = height//2
white = (255, 255, 255) # canvas back
global x1,x2,y1,y2

def save():
    # save image to hard drive
    filename = "user_input.jpg"
    output_image.save(filename)



def paint(event):
    x1, y1 = (event.x - 1), (event.y - 1)
    x2, y2 = (event.x + 1), (event.y + 1)
    canvas.create_oval(x1, y1, x2, y2, fill="black",width=5)
    draw.line([x1, y1, x2, y2],fill="black",width=5)

    return x1,x2,y1,y2
    
def clear():
    canvas.delete('all')
    filename = "user_input.jpg"
    output_image.save(filename)
    #ImageGrab.grab((x1, y1, x1+x2, y1+y2)).save('user_input.jpg')

master = Tk()

# create a tkinter canvas to draw on
canvas = Canvas(master, width=width, height=height, bg='white')
canvas.pack()

# create an empty PIL image and draw object to draw on
output_image = PIL.Image.new("RGB", (width, height), white)
draw = ImageDraw.Draw(output_image)
canvas.pack(expand=YES, fill=BOTH)
canvas.bind("<B1-Motion>", paint)

# add a button to save the image
button=Button(text="save",command=save)
clearButton = Button(text='clear', command=clear)

button.pack()
clearButton.pack()


master.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hasan\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-f9d911dce305>", line 24, in clear
#     ImageGrab.grab((10,10,10,10)).save('user_input.jpg')
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\Image.py", line 2172, in save
#     save_handler(self, fp, filename)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py", line 784, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\ImageFile.py", line 527, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hasan\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-f9d911dce305>", line 24, in clear
#     ImageGrab.grab((10,10,10,10)).save('user_input.jpg')
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\Image.py", line 2172, in save
#     save_handler(self, fp, filename)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py", line 784, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\ImageFile.py", line 527, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hasan\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-f9d911dce305>", line 24, in clear
#     ImageGrab.grab((10,10,10,10)).save('user_input.jpg')
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\Image.py", line 2172, in save
#     save_handler(self, fp, filename)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py", line 784, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\ImageFile.py", line 527, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hasan\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-f9d911dce305>", line 24, in clear
#     ImageGrab.grab((10,10,10,10)).save('user_input.jpg')
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\Image.py", line 2172, in save
#     save_handler(self, fp, filename)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py", line 784, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\ImageFile.py", line 527, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hasan\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-f9d911dce305>", line 24, in clear
#     ImageGrab.grab((10,10,10,10)).save('user_input.jpg')
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\Image.py", line 2172, in save
#     save_handler(self, fp, filename)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py", line 784, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#   File "C:\Users\hasan\anaconda3\lib\site-packages\PIL\ImageFile.py", line 527, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image
